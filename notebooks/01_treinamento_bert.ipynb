# %% [markdown]
# # Classificação de Comentários de Notícias com BERT

# %% [markdown]
# ## 0. Instalação de dependências

# %%
# !pip install transformers torch scikit-learn pandas numpy matplotlib

# %% [markdown]
# ## 1. Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Carregamento e preparação dos dados

# %% [markdown]
# *(Aqui vamos ler o CSV, limpar os dados e dividir em treino/val/teste.)*

# %% [markdown]
# ## 3. Tokenização e criação dos DataLoaders

# %% [markdown]
# ## 4. Definição do modelo BERT para classificação

# %% [markdown]
# ## 5. Loop de treinamento (train/val)

# %% [markdown]
# ## 6. Avaliação no conjunto de teste

# %% [markdown]
# ## 7. Função de inferência para novos textos

# %% [markdown]
# ## 8. Salvando resultados e conclusões
